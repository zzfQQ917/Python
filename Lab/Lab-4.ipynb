# %%
d = {'kim':3, 'park':2, 'youn':1}

values = list(d.values())

for idk in values:
    print(idk,end=' ')
# Out:
# 3 2 1

# %%
num_of_menu = int(input('총 메뉴 수: '))
menu_board = {}

for limit in range(1, num_of_menu+1):
    menu_title = input(f'{limit}번째 추가할 음식명: ')
    menu_price = int(input(f'{menu_title} 1인분의 가격: '))

    menu_board[menu_title] = menu_price

def alert_cost():
    print('-------------------------')
    for selection in list(menu_board.items()):
        print(f'{selection[0]}  {selection[1]}')
    print('-------------------------')

alert_cost()
existance = input('메뉴 중 하나를 입력하세요: ')
if existance in menu_board:
    print(f'\n{existance}은(는) {menu_board[existance]}입니다. ')

else:
    print(f'\n{existance}은(는) 메뉴에 없습니다. ')
# Out:
# -------------------------
# 김밥, 3500
# 떡볶이, 2000
# 어묵, 1500
# -------------------------
#
# 어묵은(는) 1500입니다.

# %%
scores = {
    'Tom':80,
    'Jane':75,
    'John':90
}

renewal = {

}

for enhancement in list(scores.values()):
    renewed_tom = scores['Tom'] + 5
    renewed_jane = scores['Jane'] + 5
    renewed_john = scores['John'] + 5

# %%
items = ['apple', 'banana', 'apple', 'orange', 'banana']
renewed_items = []

for lack_of_accumulated in items:
    if lack_of_accumulated not in renewed_items:
        renewed_items.append(lack_of_accumulated)

print(renewed_items)
# Out:
# ['apple', 'banana', 'orange']

# %%
sentence = "apple banana apple orange banana apple"
emt = {

}
resolution = sentence.split(' ')

for singularity in resolution:
    if singularity in emt:
        emt[singularity] += 1
    
    else:
        emt[singularity] = 1
print(emt)
# Out:
# {'apple': 3, 'banana': 2, 'orange': 1}

# %%
basic = ['a', 'b', 'c']
fundamental = {}
integer = 0

for alp in basic:
    fundamental[integer] = alp
    integer += 1
    
print(fundamental)
# Out:
# {0: 'a', 1: 'b', 2: 'c'}

# %%
votes = ['A', 'B', 'A', 'C', 'B', 'A']
d = {}
num = 0
none = ''

for utmost in votes:
    if utmost in d:
        d[utmost] += 1
        
    else:
        d[utmost] = 1

for accumulated, cover in d.items():
    if cover > num:
        num = cover
        none = accumulated
    
print(none)
# Out:
# A

# %%
nums = [1, 2, 3, 4, 5]
numss = []

for square in nums:
    if square % 2 == 0:
        square **= 2
        numss.append(square)
    
    else:
        numss.append(square)
print(numss)
# Out:
# [1, 4, 3, 16, 5]

# %%
txts = [' hello ', ' world', 'apple ']
lack_of_space = []

for annihilation in txts:
    unspaced = annihilation.replace(' ', '')
    lack_of_space.append(unspaced)

print(lack_of_space)
# Out:
# ['hello', 'world', 'apple']

# %%
items = [1, 2, 2, 3, 3, 4, 5, 5]
sum_of_duplication = []

for overload in items:
    if overload not in sum_of_duplication:
        sum_of_duplication.remove(overload)
        sum_of_duplication.count(overload)

print(sum_of_duplication)
# Out:
# [1, 2, 3, 4, 5]

# %%
matrix = [
    [1, 2, 3],
    [4, 5, 6],
    [7, 8, 9]
]
var = 0

for increment in matrix:
    print(increment[var])
    var += 1
# Out:
# 1
# 5
# 9

# %%
data = {'a':1, 'b':2, 'c':1, 'd':2, 'e':3}
newer_data = {}

for k, v in data.items():
    if v not in newer_data:
        newer_data[v] = [k]
    
    else:
        newer_data[v].append(k)
print(newer_data)
# Out:
# {1: ['a', 'c'], 2: ['b', 'd'], 3: ['e']}

# %%
students = {
    's1': {'name': 'Tom', 'age': 20},
    's2': {'name': 'Jane', 'age': 21},
    's3': {'name':'Mike', 'age': 21}
}
empty = []

for essential_name in students.values():
    empty.append(essential_name['name'])
print(empty)
# Out:
# ['Tom', 'Jane', 'Mike']

# %%
words = ['apple', 'banana', 'cherry']
space = {}

for k in words:
    v = len(k)
    space[k] = v
print(space)
# Out:
# {'apple': 5, 'banana': 6, 'cherry': 6}

# %%
text = 'hello world'
t = {}

for var in text:
    if var not in t:
        t[var] = 1
    
    else:
        t[var] += 1
print(t)
# Out:
# {'h': 1, 'e': 1, 'l': 3, 'o': 2, ' ': 1, 'w': 1, 'r': 1, 'd': 1}

# %%
scores = {'Tom': 88, 'Jane': 92, 'Mike': 65}

for name, grade in scores.items():
    if grade >= 90:
        scores[name] = 'A'
    
    elif grade >= 80:
        scores[name] = 'B'
    
    elif grade >= 70:
        scores[name] = 'C'
    
    else:
        scores[name] = 'F'
print(scores)
# Out:
# {'Tom': 'B', 'Jane': 'A', 'Mike': 'F'}

# %%
key = ['name', 'age', 'city']
value = ['Tomb', 25, 'Seoul']
empty = {}

for index, k in enumerate(key):
    empty[k] = value[index]

print(empty)
# Out:
# {'name': 'Tomb', 'age': 25, 'city': 'Seoul'}

# %%
A = [1, 2, 3, 4]
B = [3, 4, 5, 6]
new_list = []

for discrimination in A:
    if discrimination not in B:
        pass
    
    else:
        new_list.append(discrimination)
print(new_list)
# Out:
# [3, 4]

# %%
nums = [1, 2, 3, 4, 5]
num_dict = {}

for num in nums:
    if num % 2 == 0:
        num_dict[num] = 'even'

    else:
        num_dict[num] = 'odd'
print(num_dict)
# Out:
# {1: 'odd', 2: 'even', 3: 'odd', 4: 'even', 5: 'odd'}

# %%
undefined_dict = {
    'idk': 1,
    'idk2': 2,
    'idk3': 3,
    'idk4': 4
}

var = list(undefined_dict.values())
print(max(var))
# Out:
# 4

# %%
data = {
    'a': 1,
    'b': 2,
    'c': 1,
    'd': 3
    }
purified_data = {}

for var, purification in data.items():
    if purification not in purified_data.values():
        purified_data[var] = purification
    
    else:
        pass

print(purified_data)
# Out:
# {'a': 1, 'b': 2, 'd': 3}

# %%
posts = [
    {'title': 'Hello World', 'Likes': 50},
    {'title': 'Python Tips', 'Likes': 120},
    {'title': 'Django vs Flask', 'Likes': 200}
]

for anatomy in posts:
    for key, likes in anatomy.items():
        if key == 'Likes' and likes >= 100:
            print(anatomy[key])
        
        else:
            pass
# Out:
# 120
# 200

# %%
articles = [
    {'id': 1, 'comments': ['Good!', 'Nice post!']},
    {'id': 2, 'comments': []},
    {'id': 3, 'comments': ['Great', 'Thanks!', 'Wow!']}
]

for var in articles:
    print(len(var['comments']))
# Out:
# 2
# 0
# 3

# %%
users = [
    {'name': 'Tom', 'email': 'tom@example.com'},
    {'name': 'Jane'},
    {'name': 'Mike', 'email': 'mike@example.com'}
]

for gmail in users:
    if 'email' in gmail.keys():
        print(gmail['name'])
# Out:
# Tom
# Mike

# %%
order = {
    'order_id': 1001,
    'items': [
        {'product': {'name': 'laptop', 'price': 1200}},
        {'product': {'name': 'Mouse', 'price': 25}},
        {'product': {'name': 'Keyboard', 'price': 70}}
    ]
}
product_title = []

for mass_production in order['items']:
    specific = mass_production['product']
    product_title.append(specific['name'])
print(product_title)
# Out:
# ['laptop', 'Mouse', 'Keyboard']

# %%
users = [
    {'name': 'Alice', 'is_active': True},
    {'name': 'Bob', 'is_active': False},
    {'name': 'Charlie', 'is_active': True}
]
onlines = []

for discrimination in users:
    if discrimination['is_active'] == True:
        onlines.append(discrimination['name'])
    
    else:
        pass
print(onlines)
# Out:
# ['Alice', 'Charlie']

# %%
students = [
    {'name': 'Tom', 'scores': {'math': 80, 'english': 70}},
    {'name': 'Jane', 'scores': {'math': 90, 'english': 85}},
    {'name': 'Mike', 'scores': {'math': 60, 'english': 75}}
]

for overall_grade in students:
    print(overall_grade['name'])
    addition = overall_grade['scores']
    transcript = addition['math'] + addition['english']
    print(transcript)
# Out:
# Tom
# 150
# Jane
# 175
# Mike
# 135

# %%
contacts = [
    {'name': 'Anna', 'email': 'a@a.com'},
    {'name': 'Brian', 'phone': '010-1234-5678'},
    {'name': 'Cathy', 'email': 'c@c.com', 'phone': '010-2345-6789'}
]
phone_owner = []
for verify in contacts:
    if 'phone' in verify.keys():
        phone_owner.append(verify['name'])
print(phone_owner)
# Out:
# ['Brian', 'Cathy']

# %%
people = [
    {'name': 'A', 'age': 21, 'city': 'Seoul'},
    {'name': 'B', 'age': 19, 'city': 'Busan'},
    {'name': 'C', 'age': 25, 'city': 'Seoul'}
]
seoul = []
for regional_issue in people:
    if regional_issue['city'] == 'Seoul' and regional_issue['age'] >= 20:
        seoul.append(regional_issue['name'])
print(seoul)
# Out:
# ['A', 'C']

# %%
products = [
    {'product_id': 'P01', 'name': 'Chair'},
    {'product_id': 'P02', 'name': 'Desk'},
    {'product_id': 'P03', 'name': 'Lamp'}
]
new_dict = {}
for produce in products:
    new_dict[produce['product_id']] = produce['name']
print(new_dict)
# Out:
# {'P01': 'Chair', 'P02': 'Desk', 'P03': 'Lamp'}
